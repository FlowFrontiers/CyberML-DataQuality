# %% [markdown]
# ## Comparison of Confusion Matrices

# %% [markdown]
# ### Binary Classification

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import os
from matplotlib import rcParams

# Set font to CMU Serif if available
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['CMU Serif']  # Replace with the name of the font if different

# File paths
file_paths = [
    '../1-CICIDS-2017/datasets/no_feat_sel/binary-class/confusion_matrices.json',
    '../2-WTMC-2021/datasets/no_feat_sel/binary-class/confusion_matrices.json',
    '../3-CRiSIS-2022/datasets/no_feat_sel/binary-class/confusion_matrices.json',
    '../4-NFS-2023/NFS-2023-nTE/no_feat_sel/binary-class/confusion_matrices.json',
    '../4-NFS-2023/NFS-2023-TE/no_feat_sel/binary-class/confusion_matrices.json'
]

# Days of the week
days = ["Tuesday", "Wednesday", "Thursday", "Friday"]

# Function to plot and save confusion matrix
def plot_confusion_matrix(matrix, labels, title, file_path):
    plt.figure(figsize=(7, 6))  # Adjust for compactness
    sns.heatmap(matrix, annot=True, fmt=".4f", 
                cmap="Blues",
#                 cmap="Greens",
#                 cmap="coolwarm",
                xticklabels=labels, yticklabels=labels, 
                cbar=False,
                annot_kws={"size": 20}
#                 , center=0.95
               )
#     plt.title(title, fontsize=10)
#     plt.ylabel('True label', fontsize=8)
#     plt.xlabel('Predicted label', fontsize=8)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.tight_layout()  # Adjust layout
    plt.savefig(file_path)
    plt.close()

# Process each file and each day
for file_path in file_paths:
    with open(file_path, 'r') as file:
        json_data = json.load(file)

    # Determine the directory for confusion matrices
    confusion_matrix_directory = os.path.dirname(file_path)

    # Create the directory
    os.makedirs(confusion_matrix_directory, exist_ok=True)

    for day in days:
        if day in json_data:
            matrix = json_data[day]['matrix']
            labels = json_data[day]['labels']
            title = f'Confusion Matrix for {day}'
            file_name = f'{confusion_matrix_directory}/b_cm_{day}.png'
            plot_confusion_matrix(matrix, labels, title, file_name)

# %% [markdown]
# #### The same just better visual comparison

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import os
from matplotlib import rcParams

# Set font to CMU Serif if available
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['CMU Serif']

# File paths and row labels
file_paths = [
    '../1-CICIDS-2017/datasets/no_feat_sel/binary-class/confusion_matrices.json',
    '../2-WTMC-2021/datasets/no_feat_sel/binary-class/confusion_matrices.json',
    '../3-CRiSIS-2022/datasets/no_feat_sel/binary-class/confusion_matrices.json',
    '../4-NFS-2023/NFS-2023-nTE/no_feat_sel/binary-class/confusion_matrices.json',
    '../4-NFS-2023/NFS-2023-TE/no_feat_sel/binary-class/confusion_matrices.json'
]
row_labels = ["CICIDS-2017", "WTMC-2021", "CRiSIS-2022", "NFS-2023-nTE", "NFS-2023-TE"]

# Days of the week
days = ["Tuesday", "Wednesday", "Thursday", "Friday"]

# Create a 5x4 grid of subplots for confusion matrices
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(20, 25))

# Iterate over each file and each day
for row, file_path in enumerate(file_paths):
    with open(file_path, 'r') as file:
        json_data = json.load(file)

    for col, day in enumerate(days):
        ax = axes[row, col]
        if day in json_data:
            matrix = json_data[day]['matrix']
            labels = json_data[day]['labels']
            sns.heatmap(matrix, annot=True, fmt=".4f", cmap="Blues", xticklabels=labels, yticklabels=labels, cbar=False, annot_kws={"size": 20}, ax=ax)
            ax.set_title(f'{day}', fontsize=14)
            ax.tick_params(labelsize=14)
        else:
            ax.axis('off')  # Turn off axis if no data for that day

# Manually adjusted positions for each row label
label_positions = [0.865, 0.68, 0.5, 0.31, 0.13]
            
# Add row labels
for i, label in enumerate(row_labels):
    fig.text(0.01, label_positions[i], label, ha='center', va='center', rotation='vertical', fontsize=14)

# Set the main title and adjust layout
fig.suptitle("Binary Classification Confusion Matrices Comparison", fontsize=16)
plt.tight_layout(rect=[0.02, 0.03, 1, 0.97])

# Ensure the directory exists and save the plot
output_directory = 'fig'
os.makedirs(output_directory, exist_ok=True)
plt.savefig(os.path.join(output_directory, 'binary-confusion-matrices.png'))
plt.show()

# %% [markdown]
# #### The same just for easier LaTeX import

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import os
from matplotlib import rcParams

# Set font to CMU Serif if available
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['CMU Serif']  # Replace with the name of the font if different

# File paths
file_paths = [
    '../1-CICIDS-2017/datasets/no_feat_sel/binary-class/confusion_matrices.json',
    '../2-WTMC-2021/datasets/no_feat_sel/binary-class/confusion_matrices.json',
    '../3-CRiSIS-2022/datasets/no_feat_sel/binary-class/confusion_matrices.json',
    '../4-NFS-2023/NFS-2023-nTE/no_feat_sel/binary-class/confusion_matrices.json',
    '../4-NFS-2023/NFS-2023-TE/no_feat_sel/binary-class/confusion_matrices.json'
]

CMP_PATH = "cm-plots"

# Days of the week
days = ["Tuesday", "Wednesday", "Thursday", "Friday"]

# Function to plot and save confusion matrix
def plot_confusion_matrix(matrix, labels, title, file_path):
    plt.figure(figsize=(7, 6))  # Adjust for compactness
    sns.heatmap(matrix, annot=True, fmt=".4f", 
                cmap="Blues",
#                 cmap="Greens",
#                 cmap="coolwarm",
                xticklabels=labels, yticklabels=labels, 
                cbar=False,
                annot_kws={"size": 34}
#                 , center=0.95
               )
#     plt.title(title, fontsize=10)
#     plt.ylabel('True label', fontsize=8)
#     plt.xlabel('Predicted label', fontsize=8)
    plt.xticks(fontsize=28)
    plt.yticks(fontsize=28)
    plt.tight_layout()  # Adjust layout
    plt.savefig(file_path)
    plt.close()

# Process each file and each day
for file_path in file_paths:
    with open(file_path, 'r') as file:
        json_data = json.load(file)

    # Determine the directory for confusion matrices
    if 'NFS-2023-nTE' in file_path:
        confusion_matrix_directory = f'{CMP_PATH}/4-NFS-2023-nTE'
    elif 'NFS-2023-TE' in file_path:
        confusion_matrix_directory = f'{CMP_PATH}/5-NFS-2023-TE'
    else:
        main_directory = file_path.split('/')[1]
        confusion_matrix_directory = f'{CMP_PATH}/{main_directory}'

    # Create the directory
    os.makedirs(confusion_matrix_directory, exist_ok=True)

    for day in days:
        if day in json_data:
            matrix = json_data[day]['matrix']
            labels = json_data[day]['labels']
            title = f'Confusion Matrix for {day}'
            file_name = f'{confusion_matrix_directory}/b_cm_{day}.png'
            plot_confusion_matrix(matrix, labels, title, file_name)

# %% [markdown]
# ### Multi-class classification

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import os
from matplotlib import rcParams

# Set font to CMU Serif if available
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['CMU Serif']  # Replace with the name of the font if different

# File paths
file_paths = [
    '../1-CICIDS-2017/datasets/no_feat_sel/multi-class/confusion_matrices.json',
    '../2-WTMC-2021/datasets/no_feat_sel/multi-class/confusion_matrices.json',
    '../3-CRiSIS-2022/datasets/no_feat_sel/multi-class/confusion_matrices.json',
    '../4-NFS-2023/NFS-2023-nTE/no_feat_sel/multi-class/confusion_matrices.json',
    '../4-NFS-2023/NFS-2023-TE/no_feat_sel/multi-class/confusion_matrices.json'
]

CMP_PATH = "cm-plots"

# Label mapping dictionary
label_mapping = {
    "DoS GoldenEye": "GoldenE.",
    "DoS Hulk": "Hulk",
    "DoS Slowhttptest": "SlowHTTP",
    "DoS slowloris": "Slowlo.",
    "Web Attack - Brute Force": "Brute F.",
    "Web Attack - Sql Injection": "SQL Inj.",
    "Web Attack - XSS": "XSS",
    "Infiltration": "Infiltr.",
    "Port_scan": "PortScan",
    "Heartbleed": "Heartbl."
}

# Days of the week
days = ["Tuesday", "Wednesday", "Thursday", "Friday"]

# Function to plot and save confusion matrix
def plot_confusion_matrix(matrix, labels, title, file_path):
    
    # Update labels using the mapping
    updated_labels = [label_mapping.get(label, label) for label in labels]
    
    plt.figure(figsize=(7, 6))  # Adjust for compactness
    sns.heatmap(matrix, annot=True, fmt=".4f", 
                cmap="Blues",
#                 cmap="Greens",
#                 cmap="coolwarm",
#                 cmap="RdYlBu",
                xticklabels=updated_labels, yticklabels=updated_labels, 
                cbar=False,
                annot_kws={"size": 20}
#                 , center=0.95
               )
#     plt.title(title, fontsize=10)
#     plt.ylabel('True label', fontsize=8)
#     plt.xlabel('Predicted label', fontsize=8)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.tight_layout()  # Adjust layout
    plt.savefig(file_path)
    plt.close()

# Process each file and each day
for file_path in file_paths:
    with open(file_path, 'r') as file:
        json_data = json.load(file)

    # Determine the directory for confusion matrices
    confusion_matrix_directory = os.path.dirname(file_path)

    # Create the directory
    os.makedirs(confusion_matrix_directory, exist_ok=True)

    for day in days:
        if day in json_data:
            matrix = json_data[day]['matrix']
            labels = json_data[day]['labels']
            title = f'Confusion Matrix for {day}'
            file_name = f'{confusion_matrix_directory}/m_cm_{day}.png'
            plot_confusion_matrix(matrix, labels, title, file_name)

# %% [markdown]
# #### The same just better visual comparison

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import os
from matplotlib import rcParams

# Set font to CMU Serif if available
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['CMU Serif']  # Replace with the name of the font if different

# File paths
file_paths = [
    '../1-CICIDS-2017/datasets/no_feat_sel/multi-class/confusion_matrices.json',
    '../2-WTMC-2021/datasets/no_feat_sel/multi-class/confusion_matrices.json',
    '../3-CRiSIS-2022/datasets/no_feat_sel/multi-class/confusion_matrices.json',
    '../4-NFS-2023/NFS-2023-nTE/no_feat_sel/multi-class/confusion_matrices.json',
    '../4-NFS-2023/NFS-2023-TE/no_feat_sel/multi-class/confusion_matrices.json'
]

CMP_PATH = "cm-plots"

# Label mapping dictionary
label_mapping = {
    "DoS GoldenEye": "GoldenE.",
    "DoS Hulk": "Hulk",
    "DoS Slowhttptest": "SlowHTTP",
    "DoS slowloris": "Slowlo.",
    "Web Attack - Brute Force": "Brute F.",
    "Web Attack - Sql Injection": "SQL Inj.",
    "Web Attack - XSS": "XSS",
    "Infiltration": "Infiltr.",
    "Port_scan": "PortScan",
    "Heartbleed": "Heartbl."
}

row_labels = ["CICIDS-2017", "WTMC-2021", "CRiSIS-2022", "NFS-2023-nTE", "NFS-2023-TE"]

# Days of the week
days = ["Tuesday", "Wednesday", "Thursday", "Friday"]

# Create a 5x4 grid of subplots for confusion matrices
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(20, 25))

# Iterate over each file and each day
for row, file_path in enumerate(file_paths):
    with open(file_path, 'r') as file:
        json_data = json.load(file)

    for col, day in enumerate(days):
        ax = axes[row, col]
        if day in json_data:
            matrix = json_data[day]['matrix']
            labels = json_data[day]['labels']
            
            # Update labels using the mapping
            updated_labels = [label_mapping.get(label, label) for label in labels]
            
            sns.heatmap(matrix, annot=True, fmt=".4f", cmap="Blues", xticklabels=updated_labels, yticklabels=updated_labels, cbar=False, annot_kws={"size": 14}, ax=ax)
            ax.set_title(f'{day}', fontsize=10)
            ax.tick_params(labelsize=10)
        else:
            ax.axis('off')  # Turn off axis if no data for that day

# Manually adjusted positions for each row label
label_positions = [0.865, 0.68, 0.5, 0.31, 0.13]
            
# Add row labels
for i, label in enumerate(row_labels):
    fig.text(0.01, label_positions[i], label, ha='center', va='center', rotation='vertical', fontsize=14)

# Set the main title and adjust layout
fig.suptitle("Multi-class Classification Confusion Matrices Comparison", fontsize=16)
plt.tight_layout(rect=[0.02, 0.03, 1, 0.97])

# Ensure the directory exists and save the plot
output_directory = 'fig'
os.makedirs(output_directory, exist_ok=True)
plt.savefig(os.path.join(output_directory, 'multi-confusion-matrices.png'))
plt.show()

# %% [markdown]
# #### The same just for easier LaTeX import

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import os
from matplotlib import rcParams

# Set font to CMU Serif if available
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['CMU Serif']  # Replace with the name of the font if different

# File paths
file_paths = [
    '../1-CICIDS-2017/datasets/no_feat_sel/multi-class/confusion_matrices.json',
    '../2-WTMC-2021/datasets/no_feat_sel/multi-class/confusion_matrices.json',
    '../3-CRiSIS-2022/datasets/no_feat_sel/multi-class/confusion_matrices.json',
    '../4-NFS-2023/NFS-2023-nTE/no_feat_sel/multi-class/confusion_matrices.json',
    '../4-NFS-2023/NFS-2023-TE/no_feat_sel/multi-class/confusion_matrices.json'
]

CMP_PATH = "cm-plots"

# Label mapping dictionary
label_mapping = {
    "DoS GoldenEye": "GoldenE.",
    "DoS Hulk": "Hulk",
    "DoS Slowhttptest": "SlowHTTP",
    "DoS slowloris": "Slowlo.",
    "Web Attack - Brute Force": "Brute F.",
    "Web Attack - Sql Injection": "SQL Inj.",
    "Web Attack - XSS": "XSS",
    "Infiltration": "Infiltr.",
    "Port_scan": "PortScan",
    "Heartbleed": "Heartbl."
}

# Days of the week
days = ["Tuesday", "Wednesday", "Thursday", "Friday"]

# Function to plot and save confusion matrix
def plot_confusion_matrix(matrix, labels, title, file_path):
    
    # Update labels using the mapping
    updated_labels = [label_mapping.get(label, label) for label in labels]
    
    plt.figure(figsize=(7, 6))  # Adjust for compactness
    sns.heatmap(matrix, annot=True, fmt=".4f", 
                cmap="Blues",
#                 cmap="Greens",
#                 cmap="coolwarm",
#                 cmap="RdYlBu",
                xticklabels=updated_labels, yticklabels=updated_labels, 
                cbar=False,
                annot_kws={"size": 20}
#                 , center=0.95
               )
#     plt.title(title, fontsize=10)
#     plt.ylabel('True label', fontsize=8)
#     plt.xlabel('Predicted label', fontsize=8)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.tight_layout()  # Adjust layout
    plt.savefig(file_path)
    plt.close()

# Process each file and each day
for file_path in file_paths:
    with open(file_path, 'r') as file:
        json_data = json.load(file)

    # Determine the directory for confusion matrices
    if 'NFS-2023-nTE' in file_path:
        confusion_matrix_directory = f'{CMP_PATH}/4-NFS-2023-nTE'
    elif 'NFS-2023-TE' in file_path:
        confusion_matrix_directory = f'{CMP_PATH}/5-NFS-2023-TE'
    else:
        main_directory = file_path.split('/')[1]
        confusion_matrix_directory = f'{CMP_PATH}/{main_directory}'

    # Create the directory
    os.makedirs(confusion_matrix_directory, exist_ok=True)

    for day in days:
        if day in json_data:
            matrix = json_data[day]['matrix']
            labels = json_data[day]['labels']
            title = f'Confusion Matrix for {day}'
            file_name = f'{confusion_matrix_directory}/m_cm_{day}.png'
            plot_confusion_matrix(matrix, labels, title, file_name)
